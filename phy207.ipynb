# %%
from fourier_funcs import *
from IPython.display import Video

# %%
Video('4_colors_string_no_ball.mp4',html_attributes="controls loop autoplay")
# Out:
# <video src="4_colors_string_no_ball.mp4" controls loop autoplay  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
Video('ball_height_time.mp4',html_attributes="controls loop autoplay")
# Out:
# <video src="ball_height_time.mp4" controls loop autoplay  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
Video('standing_wave.mp4',html_attributes="controls loop autoplay")
# Out:
# <video src="standing_wave.mp4" controls loop autoplay  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
make_complex_tone(n_tones = 5, pitched = True)
# Out:
# Incorrect shape for phase offset array, setting random phases.

# %%
drawing = draw()

# %%
process_drawing(drawing,10,one_by_one=True)
